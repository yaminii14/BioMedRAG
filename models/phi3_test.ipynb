# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-c50f6d16-9534-4154-8d3a-b7cf651b7273" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c50f6d16-9534-4154-8d3a-b7cf651b7273">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !unzip -q BioMedRAG-main.zip

# %%
# %cd BioMedRAG-main
# !find . -type f | head -100
# Out:
# /content/BioMedRAG-main
# ./data/__pycache__/create_database.cpython-312.pyc
# ./data/__pycache__/build_faiss_index.cpython-312.pyc
# ./data/__pycache__/__init__.cpython-312.pyc
# ./data/__init__.py
# ./data/create_database.py
# ./data/faiss_index.bin
# ./data/build_faiss_index.py
# ./data/load_pubmedqa.py
# ./data/pmid_map.pkl
# ./data/pubmed.db
# ./debug_rag.py
# ./experiments/__pycache__/run_comparison.cpython-312.pyc
# ./experiments/__pycache__/__init__.cpython-312.pyc
# ./experiments/__init__.py
# ./experiments/run_comparison.py
# ./test_basic.py
# ./requirements.txt
# ./test_rag.py
# ./core/__pycache__/__init__.cpython-313.pyc
# ./core/__pycache__/retriever.cpython-312.pyc
# ./core/__pycache__/embedder.cpython-312.pyc
# ./core/__pycache__/__init__.cpython-312.pyc
# ./core/__pycache__/retriever.cpython-313.pyc
# ./core/__pycache__/rag_pipeline.cpython-312.pyc
# ./core/__init__.py
# ./core/rag_pipeline.py
# ./core/evaluator.py
# ./core/retriever.py
# ./core/embedder.py
# ...

# %%
# !cat models/phi3_model.py
# Out:
# """
# Phi-3 Mini Model Implementation
# Microsoft's 3.8B parameter lightweight model
# OPTIMIZED FOR CPU - Uses pipeline for stable generation
# STANDALONE VERSION - No base class dependency
# """
# import torch
# from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline
# from typing import List, Dict
#
# class Phi3Model:
#     """Microsoft Phi-3 Mini 4K Instruct model."""
#
#     def __init__(self):
#         self.model_name = "microsoft/Phi-3-mini-4k-instruct"
#         self.device = "cuda" if torch.cuda.is_available() else "cpu"
#         self.model = None
#         self.tokenizer = None
#         self.pipe = None  # Use pipeline for CPU stability
#         self.load_model()
#
#     def load_model(self):
#         """Load the Phi-3 model and tokenizer."""
#         print(f"Loading {self.model_name} on {self.device}...")
#
#         # Load tokenizer
#         self.tokenizer = AutoTokenizer.from_pretrained(
#             self.model_name,
# ...

# %%
# !head -100 models/phi3_model.py
# Out:
# """
# Phi-3 Mini Model Implementation
# Microsoft's 3.8B parameter lightweight model
# OPTIMIZED FOR CPU - Uses pipeline for stable generation
# STANDALONE VERSION - No base class dependency
# """
# import torch
# from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline
# from typing import List, Dict
#
# class Phi3Model:
#     """Microsoft Phi-3 Mini 4K Instruct model."""
#
#     def __init__(self):
#         self.model_name = "microsoft/Phi-3-mini-4k-instruct"
#         self.device = "cuda" if torch.cuda.is_available() else "cpu"
#         self.model = None
#         self.tokenizer = None
#         self.pipe = None  # Use pipeline for CPU stability
#         self.load_model()
#
#     def load_model(self):
#         """Load the Phi-3 model and tokenizer."""
#         print(f"Loading {self.model_name} on {self.device}...")
#
#         # Load tokenizer
#         self.tokenizer = AutoTokenizer.from_pretrained(
#             self.model_name,
# ...

# %%
# %cd /content/BioMedRAG-main
# !pip install -r requirements.txt
# Out:
# /content/BioMedRAG-main
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.5/18.5 MB 76.0 MB/s eta 0:00:00
# ...

# %%
# %cd /content/BioMedRAG-main
# Out:
# /content/BioMedRAG-main

# %%
import transformers
print(transformers.__version__)
# Out:
# 5.12.1

# %%
# !pip uninstall -y transformers
# !pip install transformers==4.41.2 accelerate sentencepiece
# Out:
# Found existing installation: transformers 5.12.1
# Uninstalling transformers-5.12.1:
#   Successfully uninstalled transformers-5.12.1
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 91.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 38.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 125.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface_hub 1.20.1
#     Uninstalling huggingface_hub-1.20.1:
#       Successfully uninstalled huggingface_hub-1.20.1
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.22.2
#     Uninstalling tokenizers-0.22.2:
#       Successfully uninstalled tokenizers-0.22.2
# ...

# %%
import os
os.kill(os.getpid(), 9)

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU")
# Out:
# True
# Tesla T4

# %%
# !nl -ba models/phi3_model.py | sed -n '30,60p'
# Out:
#     30	        )
#     31
#     32	        # Set padding token
#     33	        if self.tokenizer.pad_token is None:
#     34	            self.tokenizer.pad_token = self.tokenizer.eos_token
#     35
#     36	        # Load model with optimizations
#     37	        self.model = AutoModelForCausalLM.from_pretrained(
#     38	    self.model_name,
#     39	    torch_dtype=torch.float16,
#     40	    trust_remote_code=True,
#     41	    device_map="auto"
#     42	)
#     43
#     44	        # Move to device
#     45	self.model.eval()
#     46
#     47	        # Create pipeline for stable generation on CPU
#     48	        self.pipe = pipeline(
#     49	            "text-generation",
#     50	            model=self.model,
#     51	            tokenizer=self.tokenizer,
#     52	            device=self.device if self.device == "cuda" else -1  # -1 for CPU in pipeline
#     53	        )
#     54
#     55	        # Get model info
# ...

# %%
# %cd /content/BioMedRAG-main

from models.phi3_model import Phi3Model

model = Phi3Model()
# Out:
# /content/BioMedRAG-main
# Loading microsoft/Phi-3-mini-4k-instruct on cuda...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# WARNING:transformers_modules.microsoft.Phi-3-mini-4k-instruct.f39ac1d28e925b323eae81227eaba4464caced4e.modeling_phi3:`flash-attention` package not found, consider installing for better performance: No module named 'flash_attn'.
# ...

# %%
result = model.generate(
    "What is maternal sepsis and why is it dangerous?"
)

print(result["answer"])
# Out:
# 🔄 Generating answer (this may take 1-3 minutes on CPU)...
# WARNING:transformers_modules.microsoft.Phi-3-mini-4k-instruct.f39ac1d28e925b323eae81227eaba4464caced4e.modeling_phi3:You are not running the flash-attention implementation, expect numerical differences.
# ✓ Generation complete!
# Maternal sepsis refers to a severe infection that occurs during pregnancy or within the first 42 days postpartum. It's caused by bacteria, viruses, fungi, or parasites entering the mother’s body through various routes such as childbirth, abortion procedures, cesarean sections, miscarriage, or even from an existing health condition like urinary tract infections (UTIs).
#
# Maternal sepsis can be life-threatening for both the mother and baby due to several reasons:
# ...
